# %% [markdown]
# Realizar codigo en python que permita introducir una palabra por teclado identifique sus coclaes y las convierta en mayuscula

# %%
from PIL import Image
from matplotlib import pyplot as plt
from collections import Counter
from scipy import ndimage as ndi
from skimage import feature
import scipy.misc
import numpy as np
import statistics
import random
import scipy

# %%
def open_img(img):
    route=("C:/Users/guerr/OneDrive/Imágenes/Documentos/fondos/"+img)
    img =Image.open(route)
    img.show()

open_img("cat.jpg")

# %% [markdown]
# leer una imagen con jupiter

# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np

# %matplotlib inline

plt.rcParams['figure.figsize'] = [5,2.5]

# %%
imaginicialBGR=cv2.imread('cat.jpg')
print(imaginicialBGR.shape)

plt.imshow(cv2.cvtColor(imaginicialBGR,cv2.COLOR_BGR2RGB))
plt.show()
imageRGB=plt.imread('cat.jpg')
print(imageRGB.shape)
plt.imshow(imageRGB)
plt.show()
# Out:
# (1960, 2940, 3)
# (1960, 2940, 3)

# %%
img=cv2.imread('cat.jpg')
print('size :',img.shape)
# Out:
# size : (1960, 2940, 3)

# %%
plt.imshow(img)
plt.show()

# %%
image=cv2.imread('cat.jpg',cv2.IMREAD_COLOR)
plt.figure()
plt.subplot(141)
plt.title('original')
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.subplot(142)
plt.title('canal R')
plt.imshow(image[:,:,0],cmap='gray')
#plt.axes('off')
plt.subplot(143)
plt.title('canal G')
plt.imshow(image[:,:,1],cmap='Greens')
plt.subplot(144)
plt.title('canal B')
plt.imshow(image[:,:,1],cmap='Reds')

plt.show()

# %%
import cv2 
import numpy as np
import matplotlib.pyplot as plt

image =cv2.imread('cat.jpg',cv2.IMREAD_GRAYSCALE)
#guandamos profundidad original para mostrar
original_img=image.dtype
print('profundidad original de color : ',original_img)
#transformacion de imagen a 16bits
image_16bits=np.uint16(image)
nueva_img =image_16bits.dtype

print('profundidad nueva de color : ',nueva_img)

#guardamos la imagen tratada
cv2.imwrite('image16bits.jpg', image_16bits)

img_guardada=cv2.imread('image16bits.jpg',cv2.IMREAD_UNCHANGED)

plt.figure(figsize =(10,5))

plt.subplot(121)
plt.title('original')
plt.imshow(image,cmap='gray')

plt.subplot(122)
plt.title('imagen tratada 16bits')
plt.imshow(img_guardada,cmap='gray')

plt.show()
# Out:
# profundidad original de color :  uint8
# profundidad nueva de color :  uint16
