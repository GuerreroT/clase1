# %% [markdown]
# Realizar codigo en python que permita introducir una palabra por teclado identifique sus coclaes y las convierta en mayuscula

# %%
from PIL import Image
from matplotlib import pyplot as plt
from collections import Counter
from scipy import ndimage as ndi
from skimage import feature
import scipy.misc
import numpy as np
import statistics
import random
import scipy

# %%
def open_img(img):
    route=("C:/Users/guerr/OneDrive/Imágenes/Documentos/fondos/"+img)
    img =Image.open(route)
    img.show()

open_img("cat.jpg")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 6
#       3     img =Image.open(route)
#       4     img.show()
# ----> 6 open_img("cat.jpg")
#
# Cell In[14], line 3, in open_img(img)
#       1 def open_img(img):
#       2     route=("C:/Users/guerr/OneDrive/Imágenes/Documentos/fondos/"+img)
# ----> 3     img =Image.open(route)
#       4     img.show()
#
# NameError: name 'Image' is not defined

# %% [markdown]
# leer una imagen con jupiter

# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np

# %matplotlib inline

plt.rcParams['figure.figsize'] = [10,5]

# %%
img=cv2.imread('cat.jpg')
print('size :',img.shape)
# Out:
# size : (1960, 2940, 3)

# %%
plt.imshow(img)
plt.show()
